# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# Read in datasets for review and cleaning.

# %%
data_themes = pd.read_csv(data\lego_sets_and_themes.csv)
data_sets = pd.read_csv(data\lego_sets.csv)
data_prices = pd.read_csv(data\sets_prices_over_time.csv)
                          
print(data_themes.head())

print(data_sets.head())

print(data_prices.head())
